# %% [markdown]
# <html>
# <body>
#     <h1>
#     ALGORITMOS Y PROGRAMACIÓN
#     </h1>
# </body>
# </html>

# %% [markdown]
# ## ¿Qué es un algoritmo?
#
# Es un conjunto prescrito de instrucciones o reglas bien definidas, ordenadas y finitas que permite llevar a cabo una actividad mediante pasos sucesivos que no generen dudas a quien deba hacer dicha actividad.
#
# Dados un estado inicial y una entrada, siguiendo los pasos sucesivos se llega a un estado final y se obtiene una solución.
#
# **En términos de programación, un algoritmo es una secuencia de pasos lógicos que permiten solucionar un problema.**

# %% [markdown]
# ## ¿Qué es programación?

# %% [markdown]
# Es el proceso por el cual una persona desarrolla un programa (algoritmo) valiéndose de una herramienta que le permita escribir el código (el cual puede estar en uno o varios lenguajes, tales como C++, Java, Python entre otros)

# %% [markdown]
# ## ¿Para qué sirven los diagramas de flujo?
#
# Los diagramas de flujo sirven para representar algoritmos de manera gráfica.
#
# ![image.png](attachment:image.png)
# Diagrama de flujo sencillo con los pasos a seguir si una lámpara no funciona.

# %% [markdown]
# ## ¿Qué es Pseudocódigo?
#
# **El pseudocódigo (falso lenguaje, el prefijo pseudo significa falso) es una descripción de alto nivel de un algoritmo que emplea una mezcla de lenguaje natural con algunas convenciones sintácticas propias de lenguajes de programación**, como asignaciones, ciclos y condicionales, aunque no está regido por ningún estándar. Es utilizado para describir algoritmos en libros y publicaciones científicas, y como producto intermedio durante el desarrollo de un algoritmo, como los diagramas de flujo, aunque presentan una ventaja importante sobre estos, y es que los algoritmos descritos en pseudocódigo requieren menos espacio para representar instrucciones complejas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Implementación en lenguaje C++:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ¿Qué es Python?
#
# Es un lenguaje de programación interpretado cuya filosofía hace hincapié en una sintaxis que favorezca un código legible.

# %% [markdown]
# ## ¿Qué es Anaconda?
#
# Anaconda es un distribución libre y abierta1​ de los lenguajes Python y R, utilizada en ciencia de datos, y aprendizaje automático (machine learning). Esto incluye procesamiento de grandes volúmenes de información, análisis predictivo y cómputos científicos. Está orientado a simplificar el despliegue y administración de los paquetes de software
#
# https://www.anaconda.com/enterprise/

# %% [markdown]
# ## ¿Qúe es Conda y pip?
#
# Conda al igual que pip son administradores de paquetes de código abierto.

# %% [markdown]
# ## ¿Qúe es IPython?
#
# IPython es un shell (intérprete de órdenes o intérprete de comandos) interactivo que añade funcionalidades extra al modo interactivo incluido con Python, como resaltado de líneas y errores mediante colores, una sintaxis adicional para el shell, autocompletado mediante tabulador de variables, módulos y atributos; entre otras funcionalidades. Es un componente del paquete SciPy.

# %% [markdown]
# IPython
# ![image.png](attachment:image.png)

# %% [markdown]
# Terminal en Mac
# ![image.png](attachment:image.png)

# %% [markdown]
# Símbolo del sistema o CMD ( Command prompt)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ¿Qué es Jupyter Notebook?

# %% [markdown]
# Son documentos que contienen tanto código de computadora (por ejemplo, python) como elementos de texto enriquecido (párrafos, ecuaciones, figuras, enlaces, etc.).
#
# Los documentos del cuaderno son documentos legibles por humanos que contienen la descripción del análisis y los resultados (figuras, tablas, etc.) así como documentos ejecutables que se pueden ejecutar para realizar análisis de datos.
# http://jupyter.org/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ¿Qué es una gramática de programación?
# Especificación completa de la gramática
# https://docs.python.org/3/reference/grammar.html

# %% [markdown]
# # Guía de instalación

# %% [markdown]
# 1.- Descargar Anaconda version 3.5 o superior en
#
# - Para mac https://www.anaconda.com/download/#macos
# - Para windows https://www.anaconda.com/download/#windows

# %% [markdown]
# **Nota: Solo para usuarios de windows marcar la casilla **
#
# ![image.png](attachment:image.png)
# o ver video https://www.youtube.com/watch?v=A91AB14BIz8

# %% [markdown]
# ## Abrir la terminal (cmd) en windows
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Abrir la terminal en mac
#
# Haz clic en el icono "Finder" situado en el Dock, luego selecciona "Aplicaciones > Utilidades"
# Finalmente dale doble clic al icono "Terminal"
#
# https://www.soydemac.com/abrir-terminal-mac/
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Verificar si se instalo correctamente
#
# Una vez abierto el terminal, escribe la palabra **conda** y presiona enter.

# %% [markdown]
# ## Ejecutar Jupyter
#
# En el terminal, escribe las palabras **Jupyter notebook** y presiona enter.
